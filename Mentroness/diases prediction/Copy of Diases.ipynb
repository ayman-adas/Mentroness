# %%
# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import lightgbm as lgb

from sklearn.neighbors import KNeighborsClassifier



from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv('/content/Train_data.csv')

# %%
data.dropna() #drop irrelevent column
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0     0.739597     0.650198    0.713631   0.868491           0.687433
# 1     0.121786     0.023058    0.944893   0.905372           0.507711
# 2     0.452539     0.116135    0.544560   0.400640           0.294538
# 3     0.136609     0.015605    0.419957   0.191487           0.081168
# 4     0.176737     0.752220    0.971779   0.785286           0.443880
# ...        ...          ...         ...        ...                ...
# 2346  0.012956     0.336925    0.451218   0.175006           0.734664
# 2347  0.407101     0.124738    0.983306   0.663867           0.361113
# 2348  0.344356     0.783918    0.582171   0.996841           0.065363
# 2349  0.351722     0.014278    0.898615   0.167550           0.727148
# 2350  0.032726     0.053596    0.102633   0.221356           0.153956
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0            0.529895    0.290006                 0.631045
# 1            0.403033    0.164216                 0.307553
# 2            0.382021    0.625267                 0.295122
# 3            0.166214    0.073293                 0.668719
# 4            0.439851    0.894991                 0.442159
# ...               ...         ...                      ...
# 2346         0.382770    0.656463                 0.177502
# 2347         0.663716    0.232516                 0.341056
# 2348         0.242885    0.658851                 0.543017
# 2349         0.046091    0.900434                 0.136227
# 2350         0.216573    0.312577                 0.608940
#
#       Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                        0.001328                                   0.795829
# 1                        0.207938                                   0.505562
# 2                        0.868369                                   0.026808
# 3                        0.125447                                   0.501051
# 4                        0.257288                                   0.805987
# ...                           ...                                        ...
# 2346                     0.808162                                   0.684499
# 2347                     0.847441                                   0.309766
# 2348                     0.290106                                   0.838722
# 2349                     0.134361                                   0.279219
# 2350                     0.486174                                   0.450700
#
#       ...     HbA1c  LDL Cholesterol  HDL Cholesterol       ALT       AST  \
# 0     ...  0.502665         0.215560         0.512941  0.064187  0.610827
# 1     ...  0.856810         0.652465         0.106961  0.942549  0.344261
# 2     ...  0.466795         0.387332         0.421763  0.007186  0.506918
# 3     ...  0.016256         0.040137         0.826721  0.265415  0.594148
# 4     ...  0.429431         0.146294         0.221574  0.015280  0.567115
# ...   ...       ...              ...              ...       ...       ...
# 2346  ...  0.670665         0.311568         0.595083  0.155866  0.885812
# 2347  ...  0.491185         0.701914         0.218104  0.790341  0.570902
# 2348  ...  0.141738         0.155871         0.473638  0.250535  0.387197
# 2349  ...  0.570553         0.171245         0.858352  0.362012  0.290984
# 2350  ...  0.188750         0.331887         0.562622  0.680462  0.099538
#
#       Heart Rate  Creatinine  Troponin  C-reactive Protein   Disease
# 0       0.939485    0.095512  0.465957            0.769230   Healthy
# 1       0.666368    0.659060  0.816982            0.401166  Diabetes
# 2       0.431704    0.417295  0.799074            0.779208  Thalasse
# 3       0.225756    0.490349  0.637061            0.354094    Anemia
# 4       0.841412    0.153350  0.794008            0.094970  Thalasse
# ...          ...         ...       ...                 ...       ...
# 2346    0.636125    0.132226  0.716519            0.006121  Diabetes
# 2347    0.339125    0.310964  0.310900            0.622403  Thalasse
# 2348    0.344728    0.606719  0.395145            0.134021    Anemia
# 2349    0.996873    0.882164  0.411158            0.146255  Diabetes
# 2350    0.982893    0.437285  0.288961            0.709262    Anemia
#
# [2351 rows x 25 columns]

# %%
y = data["Disease"]
x=data.drop('Disease',axis=1)

# %%
scaler = MinMaxScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
# replacing values

y.replace(['Healthy', 'Diabetes','Thalasse','Anemia','Thromboc'],

                        [0,1,2,3,4], inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
device = 'cpu'

# %%
lgb_params2 = {
            'n_estimators': 100,
            'max_depth': 6,
            'learning_rate': 0.05,
            'subsample': 0.20,
            'colsample_bytree': 0.56,
            'reg_alpha': 0.25,
            'reg_lambda': 5e-08,
            'objective': 'binary',
            'boosting_type': 'gbdt',
            'device': "cpu",
            'random_state': 0,
            'metric': 'roc_auc',
             'verbose': -1,
             'n_jobs': -1,
            'metric': 'roc_auc',
            'seed': 43}

# %%
# model= lgb.LGBMRegressor(**lgb_params2)
model= KNeighborsClassifier(n_neighbors=23)

model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=23)

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([3, 3, 2, 3, 3, 3, 1, 1, 0, 1, 1, 3, 0, 2, 3, 4, 3, 1, 1, 3, 2, 0,
#        0, 1, 1, 2, 0, 1, 4, 1, 3, 2, 1, 2, 2, 2, 3, 2, 4, 3, 1, 2, 2, 2,
#        1, 2, 1, 2, 1, 2, 3, 4, 0, 2, 3, 0, 2, 0, 1, 0, 0, 2, 2, 1, 3, 1,
#        3, 2, 2, 3, 0, 0, 0, 0, 0, 3, 4, 2, 3, 3, 3, 0, 4, 3, 0, 1, 1, 2,
#        3, 3, 3, 3, 1, 2, 2, 0, 3, 1, 2, 3, 0, 3, 0, 1, 3, 2, 3, 2, 0, 4,
#        2, 2, 2, 2, 0, 4, 1, 0, 0, 2, 2, 3, 3, 1, 2, 0, 1, 4, 3, 1, 4, 3,
#        4, 1, 0, 0, 2, 0, 3, 0, 0, 0, 2, 0, 1, 4, 1, 4, 2, 3, 3, 3, 4, 2,
#        3, 0, 0, 0, 0, 1, 2, 1, 2, 2, 4, 0, 2, 3, 1, 0, 0, 3, 0, 1, 2, 0,
#        2, 0, 3, 2, 2, 0, 1, 1, 2, 2, 1, 0, 1, 3, 1, 0, 3, 3, 1, 1, 2, 0,
#        2, 1, 3, 3, 3, 3, 2, 2, 2, 1, 3, 0, 3, 0, 4, 1, 4, 3, 2, 1, 2, 2,
#        0, 3, 1, 0, 0, 2, 0, 0, 3, 3, 0, 2, 2, 1, 1, 2, 1, 3, 2, 0, 2, 3,
#        1, 1, 3, 0, 3, 2, 3, 3, 3, 3, 0, 2, 1, 2, 4, 0, 1, 1, 4, 2, 1, 1,
#        2, 0, 0, 1, 3, 0, 0, 3, 4, 2, 3, 0, 3, 3, 2, 3, 3, 2, 0, 4, 3, 3,
#        1, 2, 0, 0, 3, 0, 3, 2, 2, 1, 1, 3, 1, 1, 1, 0, 3, 1, 3, 3, 0, 0,
#        0, 3, 1, 1, 3, 3, 3, 3, 2, 3, 1, 3, 0, 3, 0, 0, 3, 0, 3, 1, 4, 4,
#        2, 1, 1, 4, 1, 3, 2, 2, 2, 0, 2, 1, 3, 3, 1, 2, 0, 2, 1, 1, 1, 0,
#        1, 2, 0, 2, 2, 3, 2, 2, 0, 2, 2, 3, 1, 0, 0, 0, 3, 2, 0, 1, 2, 2,
#        3, 2, 2, 0, 1, 1, 3, 2, 0, 2, 2, 0, 0, 3, 2, 3, 3, 3, 0, 2, 3, 3,
#        0, 0, 0, 1, 2, 3, 1, 3, 2, 1, 1, 0, 4, 3, 1, 0, 1, 3, 0, 2, 3, 1,
#        1, 3, 3, 4, 0, 3, 1, 2, 0, 2, 1, 3, 0, 3, 1, 0, 0, 2, 3, 3, 4, 1,
#        3, 1, 0, 0, 0, 2, 1, 0, 0, 1, 3, 2, 0, 0, 1, 0, 3, 1, 2, 1, 2, 3,
#        1, 0, 4, 3, 3, 2, 2, 1, 0, 0, 3, 2, 0, 3, 0, 3, 0, 1, 3, 1, 3, 3,
#        1, 1, 4, 1, 1, 2, 3, 1, 0, 1, 2, 1, 3, 1, 3, 1, 0, 1, 0, 3, 2, 3,
#        1, 1, 1, 2, 2, 1, 4, 3, 1, 3, 0, 3, 1, 2, 3, 0, 1, 1, 3, 0, 2, 0,
#        2, 3, 3, 3, 0, 0, 0, 1, 3, 1, 0, 2, 3, 1, 2, 0, 2, 0, 3, 0, 3, 1,
#        0, 1, 2, 1, 1, 2, 0, 0, 1, 2, 1, 1, 3, 3, 0, 0, 3, 2, 0, 2, 1, 3,
#        1, 0, 1, 0, 4, 1, 3, 3, 1, 3, 1, 1, 3, 0, 2, 1, 0, 1, 2, 3, 3, 3,
#        2, 3, 3, 3, 1, 3, 1, 2, 4, 3, 2, 2, 0, 2, 3, 1, 3, 0, 2, 0, 1, 2,
#        1, 1, 2, 1, 0, 0, 1, 1, 3, 2, 0, 3, 2, 0, 0, 2, 3, 0, 3, 0, 2, 0,
#        2, 1, 2, 2, 1, 2, 0, 1, 1, 0, 3, 3, 3, 1, 2, 3, 3, 0, 3, 0, 4, 3,
#        0, 3, 3, 3, 1, 0, 3, 3, 3, 1, 1, 3, 0, 3, 1, 2, 1, 2, 4, 2, 0, 1,
#        1, 2, 0, 3, 1, 2, 2, 2, 0, 0, 1, 1, 3, 2, 0, 3, 0, 1, 0, 2, 1, 3,
#        0, 1])

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
#accuracy
metrics.accuracy_score(y_test, y_predict)
# Out:
# 1.0

# %%
#classification_report
print(metrics.classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       164
#            1       1.00      1.00      1.00       167
#            2       1.00      1.00      1.00       156
#            3       1.00      1.00      1.00       185
#            4       1.00      1.00      1.00        34
#
#     accuracy                           1.00       706
#    macro avg       1.00      1.00      1.00       706
# weighted avg       1.00      1.00      1.00       706
