# %% [markdown]
# **Imports**

# %%
import pandas as pd
import category_encoders as ce
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
# import fbprophet
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Sequential
import sklearn.metrics
import numpy as np
from datetime import datetime

# %% [markdown]
# **Read Data**

# %%
data=pd.read_csv('/content/MarketPricePrediction.csv')
# Out:
# 0         January-2005
# 1         January-2006
# 2         January-2010
# 3         January-2011
# 4         January-2012
#              ...
# 10222    December-2011
# 10223    December-2012
# 10224    December-2013
# 10225    December-2014
# 10226    December-2015
# Name: date, Length: 10227, dtype: object

# %% [markdown]
# Data preprocess

# %%
data.dropna(inplace=True)

data.drop_duplicates(inplace = True)
data = ce.BinaryEncoder().fit_transform(data)

# %% [markdown]
# **Exploratory Data Analysis (EDA):**

# %%
#identifying seasonality,
ax = data.plot(x='year', y='priceMod', figsize=(12,6))

# %%
#anomalies within the data.
n_bins = int(np.sqrt(len(data)))
plt.figure(figsize=(8, 4))
plt.hist(data, bins=n_bins)
plt.show()

# %% [markdown]
# **data Engenireeng**

# %%
data.sort_values('year', inplace=True)
data['priceMod:_lag_1'] = data['priceMod'].shift(1)
data['priceMod:_lag_5'] = data['priceMod'].shift(5)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-25d714bd4e77> in <cell line: 5>()
#       3 data['priceMod:_lag_5'] = data['priceMod'].shift(5)
#       4 from sklearn.model_selection import train_test_split
# ----> 5 x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)
#
# NameError: name 'x' is not defined

# %% [markdown]
# **Model Selection and Training:**

# %%
model = Sequential()
model.add(LSTM(4))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-012cc4d7bd70> in <cell line: 4>()
#       2 model.add(LSTM(4))
#       3 model.compile(loss='mean_squared_error', optimizer='adam')
# ----> 4 model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
#
# NameError: name 'trainX' is not defined

# %% [markdown]
# **Evaluation:**

# %%
 sklearn.metrics.mean_absolute_error(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-75fb71d030cd> in <cell line: 1>()
# ----> 1 sklearn.metrics.mean_absolute_error(y_true, y_pred)
#
# NameError: name 'y_true' is not defined

# %%
 sklearn.metrics.mean_squared_error(y_true, y_pred)

# %%
 sklearn.metrics.root_mean_squared_error(y_true, y_pred)

# %% [markdown]
# **fine-tuning**

# %%
pip install prophet
